// %%
interp.configureCompiler(_.settings.processArguments(List("-Wconf:cat=deprecation:s"), true))
interp.load.module(os.Path(s"${System.getProperty("user.dir")}/../source/load-spinal.sc"))

// %%
class Top extends Component{
    val a, b = UInt(8 bits)
    val c = a + b
}
showRtl(new Top)
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.06.08 21:49:19
// [Progress] at 0.001 : Elaborate components
// [scala-interpreter-1] WARN oshi.util.FileUtil - Configuration conflict: there is more than one oshi.properties file on the classpath: [jar:file:/Users/jayzw/Library/Caches/Coursier/v1/https/repo1.maven.org/maven2/com/github/oshi/oshi-core/6.4.0/oshi-core-6.4.0.jar!/oshi.properties, jar:file:/Users/jayzw/Library/Caches/Coursier/v1/https/repo1.maven.org/maven2/com/github/oshi/oshi-core/6.4.0/oshi-core-6.4.0-sources.jar!/oshi.properties]
// [Progress] at 0.194 : Checks and transforms
// [Progress] at 0.214 : Generate Verilog to rtl/
// [Warning] 3 signals were pruned. You can call printPruned on the backend report to get more informations.
// [Done] at 0.253
// // Generator : SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// // Component : Top
// // Git hash  : bc88ade176032b608ae9387996257abb2ecc0dc2
// // Date      : 08/06/2025, 21:49:19
//
// `timescale 1ns/1ps
//
// module Top (
// );
//
//   wire       [7:0]    a;
//   wire       [7:0]    b;
//   wire       [7:0]    c;
//
//   assign c = (a + b);
//
// endmodule
// defined class Top

// %%
class Top extends Component{
    val a, b = UInt(8 bits)
    val c = a +^ b //return 9 bits, adder with carry
}
showRtl(new Top)
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.06.08 21:49:32
// [Progress] at 13.309 : Elaborate components
// [Progress] at 13.312 : Checks and transforms
// [Progress] at 13.314 : Generate Verilog to rtl/
// [Warning] 3 signals were pruned. You can call printPruned on the backend report to get more informations.
// [Done] at 13.329
// // Generator : SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// // Component : Top
// // Git hash  : bc88ade176032b608ae9387996257abb2ecc0dc2
// // Date      : 08/06/2025, 21:49:32
//
// `timescale 1ns/1ps
//
// module Top (
// );
//
//   wire       [7:0]    a;
//   wire       [7:0]    b;
//   wire       [8:0]    c;
//
//   assign c = ({1'b0,a} + {1'b0,b});
//
// endmodule
// defined class Top

// %%
class Top extends Component{
    val a, b = UInt(8 bits)
    val c = a +| b //return 8 bits with saturation
}
showRtl(new Top)
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.06.08 21:49:52
// [Progress] at 33.828 : Elaborate components
// [Progress] at 33.833 : Checks and transforms
// [Progress] at 33.837 : Generate Verilog to rtl/
// [Warning] 4 signals were pruned. You can call printPruned on the backend report to get more informations.
// [Done] at 33.856
// // Generator : SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// // Component : Top
// // Git hash  : bc88ade176032b608ae9387996257abb2ecc0dc2
// // Date      : 08/06/2025, 21:49:52
//
// `timescale 1ns/1ps
//
// module Top (
// );
//
//   wire       [7:0]    a;
//   wire       [7:0]    b;
//   wire       [8:0]    t_c;
//   reg        [7:0]    c;
//   wire                when_UInt_l119;
//
//   assign t_c = ({1'b0,a} + {1'b0,b});
//   assign when_UInt_l119 = (|t_c[8 : 8]);
//   always @(*) begin
//     if(when_UInt_l119) begin
//       c = 8'hff;
//     end else begin
//       c = t_c[7 : 0];
//     end
//   end
//
//
// endmodule
// defined class Top
