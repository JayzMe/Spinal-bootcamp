// %%
interp.configureCompiler(_.settings.processArguments(List("-Wconf:cat=deprecation:s"), true))
interp.load.module(os.Path(s"${System.getProperty("user.dir")}/../source/load-spinal.sc"))

// %%
class Top extends Component{
    val a = in Bits(8 bits)
    val b = RegNext(a) init 0
}
showRtl(new Top)
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.06.16 20:48:10
// [Progress] at 0.000 : Elaborate components
// [scala-interpreter-1] WARN oshi.util.FileUtil - Configuration conflict: there is more than one oshi.properties file on the classpath: [jar:file:/Users/jayzw/Library/Caches/Coursier/v1/https/repo1.maven.org/maven2/com/github/oshi/oshi-core/6.4.0/oshi-core-6.4.0.jar!/oshi.properties, jar:file:/Users/jayzw/Library/Caches/Coursier/v1/https/repo1.maven.org/maven2/com/github/oshi/oshi-core/6.4.0/oshi-core-6.4.0-sources.jar!/oshi.properties]
// [Progress] at 0.232 : Checks and transforms
// [Progress] at 0.256 : Generate Verilog to rtl/
// [Warning] 1 signals were pruned. You can call printPruned on the backend report to get more informations.
// [Done] at 0.295
// // Generator : SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// // Component : Top
// // Git hash  : bc88ade176032b608ae9387996257abb2ecc0dc2
// // Date      : 16/06/2025, 20:48:10
//
// `timescale 1ns/1ps
//
// module Top (
//   input  wire [7:0]    a,
//   input  wire          clk,
//   input  wire          resetn
// );
//
//   reg        [7:0]    b;
//
//   always @(posedge clk or negedge resetn) begin
//     if(!resetn) begin
//       b <= 8'h0;
//     end else begin
//       b <= a;
//     end
//   end
//
//
// endmodule
// defined class Top

// %%
class Top extends Component {
    val myclk, myrst = in Bool()
    val a = in Bits(8 bits)
    val b = out Bits()

    new ClockingArea(ClockDomain(myclk, myrst)) {
        val reg0 = RegNext(a) init 0
        b := reg0
    }
}
showRtl(new Top)
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.06.16 20:48:17
// [Progress] at 7.003 : Elaborate components
// [Progress] at 7.005 : Checks and transforms
// (toplevel/b : out Bits[8 bits])
// [Progress] at 7.014 : Generate Verilog to rtl/
// [Done] at 7.028
// // Generator : SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// // Component : Top
// // Git hash  : bc88ade176032b608ae9387996257abb2ecc0dc2
// // Date      : 16/06/2025, 20:48:17
//
// `timescale 1ns/1ps
//
// module Top (
//   input  wire          myclk,
//   input  wire          myrst,
//   input  wire [7:0]    a,
//   output wire [7:0]    b
// );
//
//   reg        [7:0]    t_b;
//
//   assign b = t_b;
//   always @(posedge myclk or negedge myrst) begin
//     if(!myrst) begin
//       t_b <= 8'h0;
//     end else begin
//       t_b <= a;
//     end
//   end
//
//
// endmodule
// defined class Top

// %%
class Top extends Component {
    val myclk, myrst = in Bool()
    val a = in Bits(8 bits)
    val b = out Bits()
    new ClockingArea(ClockDomain(myclk, myrst, config = ClockDomainConfig(
        clockEdge = RISING,
        resetKind = ASYNC,
        resetActiveLevel = LOW
    ))) {
        val reg0 = RegNext(a) init 0
        b := reg0
    }
}
showRtl(new Top)
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.06.16 22:22:22
// [Progress] at 5652.121 : Elaborate components
// [Progress] at 5652.122 : Checks and transforms
// (toplevel/b : out Bits[8 bits])
// [Progress] at 5652.156 : Generate Verilog to rtl/
// [Done] at 5652.192
// // Generator : SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// // Component : Top
// // Git hash  : bc88ade176032b608ae9387996257abb2ecc0dc2
// // Date      : 16/06/2025, 22:22:22
//
// `timescale 1ns/1ps
//
// module Top (
//   input  wire          myclk,
//   input  wire          myrst,
//   input  wire [7:0]    a,
//   output wire [7:0]    b
// );
//
//   reg        [7:0]    t_b;
//
//   assign b = t_b;
//   always @(posedge myclk or negedge myrst) begin
//     if(!myrst) begin
//       t_b <= 8'h0;
//     end else begin
//       t_b <= a;
//     end
//   end
//
//
// endmodule
// defined class Top

// %%
class SUB extends Component {
    val a = in Bits(8 bits)
    val b = out(RegNext(a) init 0)
}
class Top extends Component {
    val myclk, myrst = in Bool()
    val cd = ClockDomain(myclk, myrst, 
        config = ClockDomainConfig(
            clockEdge = RISING,
            resetKind = ASYNC,
            resetActiveLevel = LOW
        )
    )
    val u_sub0 = cd(new SUB)
}
showRtl(new Top)
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.06.16 22:25:07
// [Progress] at 5816.973 : Elaborate components
// [Progress] at 5816.974 : Checks and transforms
// [Progress] at 5816.976 : Generate Verilog to rtl/
// [Warning] 4 signals were pruned. You can call printPruned on the backend report to get more informations.
// [Done] at 5817.056
// // Generator : SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// // Component : Top
// // Git hash  : bc88ade176032b608ae9387996257abb2ecc0dc2
// // Date      : 16/06/2025, 22:25:07
//
// `timescale 1ns/1ps
//
// module Top (
//   input  wire          myclk,
//   input  wire          myrst
// );
//
//   wire       [7:0]    u_sub0_b;
//
//   SUB u_sub0 (
//     .a     (             ), //i
//     .b     (u_sub0_b[7:0]), //o
//     .myclk (myclk        ), //i
//     .myrst (myrst        )  //i
//   );
//
// endmodule
//
// module SUB (
//   input  wire [7:0]    a,
//   output reg  [7:0]    b,
//   input  wire          myclk,
//   input  wire          myrst
// );
//
//
//   always @(posedge myclk or negedge myrst) begin
//     if(!myrst) begin
//       b <= 8'h0;
//     end else begin
//       b <= a;
//     end
//   end
//
//
// endmodule
// defined class SUB
// defined class Top
