// %%
interp.configureCompiler(_.settings.processArguments(List("-Wconf:cat=deprecation:s"), true))
interp.load.module(os.Path(s"${System.getProperty("user.dir")}/../source/load-spinal.sc"))
// Out:
// Compiling /Users/jayzw/Workspace/Personal/Spinal-bootcamp/ex/Main.sc

// %%
class Adder(width: Int) extends Component {
    val a = in(UInt(width bits))
    val b = in(UInt(width bits))
    val c = out(UInt())

    c := a + b
}
showRtl(new Adder(8))
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.05.28 23:09:20
// [Progress] at 0.000 : Elaborate components
// [scala-interpreter-1] WARN oshi.util.FileUtil - Configuration conflict: there is more than one oshi.properties file on the classpath: [jar:file:/Users/jayzw/Library/Caches/Coursier/v1/https/repo1.maven.org/maven2/com/github/oshi/oshi-core/6.4.0/oshi-core-6.4.0.jar!/oshi.properties, jar:file:/Users/jayzw/Library/Caches/Coursier/v1/https/repo1.maven.org/maven2/com/github/oshi/oshi-core/6.4.0/oshi-core-6.4.0-sources.jar!/oshi.properties]
// [Progress] at 0.203 : Checks and transforms
// (toplevel/c : out UInt[8 bits])
// [Progress] at 0.225 : Generate Verilog to rtl/
// [Done] at 0.265
// // Generator : SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// // Component : Adder
// // Git hash  : bc88ade176032b608ae9387996257abb2ecc0dc2
// // Date      : 28/05/2025, 23:09:20
//
// `timescale 1ns/1ps
//
// module Adder (
//   input  wire [7:0]    a,
//   input  wire [7:0]    b,
//   output wire [7:0]    c
// );
//
//
//   assign c = (a + b);
//
// endmodule
// defined class Adder

// %%
type Module = Component 

class Adder(width: Int) extends Module{
  val a = in(UInt(width bits))
  val b = in(UInt(width bits))
  val c = out(UInt()) 
  c := a + b
}
showRtl(new Adder(8))
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.05.28 23:09:27
// [Progress] at 6.833 : Elaborate components
// [Progress] at 6.834 : Checks and transforms
// (toplevel/c : out UInt[8 bits])
// [Progress] at 6.836 : Generate Verilog to rtl/
// [Done] at 6.853
// // Generator : SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// // Component : Adder
// // Git hash  : bc88ade176032b608ae9387996257abb2ecc0dc2
// // Date      : 28/05/2025, 23:09:27
//
// `timescale 1ns/1ps
//
// module Adder (
//   input  wire [7:0]    a,
//   input  wire [7:0]    b,
//   output wire [7:0]    c
// );
//
//
//   assign c = (a + b);
//
// endmodule
// defined type Module
// defined class Adder

// %%
import spinal.lib.soc.pinsec._
SpinalVerilog(new Pinsec(500 MHz))
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.05.28 23:10:03
// [Progress] at 43.355 : Elaborate components
// [Progress] at 43.661 : Checks and transforms
// (toplevel/io_jtag_tdo : out Bool)
// (toplevel/io_sdram_ADDR : out Bits[13 bits])
// (toplevel/io_sdram_BA : out Bits[2 bits])
// (toplevel/io_sdram_CASn : out Bool)
// (toplevel/io_sdram_CKE : out Bool)
// (toplevel/io_sdram_CSn : out Bool)
// (toplevel/io_sdram_DQM : out Bits[2 bits])
// (toplevel/io_sdram_RASn : out Bool)
// (toplevel/io_sdram_WEn : out Bool)
// (toplevel/io_sdram_DQ_write : out Bits[16 bits])
// (toplevel/io_sdram_DQ_writeEnable : out Bits[16 bits])
// (toplevel/io_gpioA_write : out Bits[32 bits])
// (toplevel/io_gpioA_writeEnable : out Bits[32 bits])
// (toplevel/io_gpioB_write : out Bits[32 bits])
// (toplevel/io_gpioB_writeEnable : out Bits[32 bits])
// (toplevel/io_uart_txd : out Bool)
// (toplevel/io_vga_vSync : out Bool)
// (toplevel/io_vga_hSync : out Bool)
// (toplevel/io_vga_colorEn : out Bool)
// (toplevel/io_vga_color_r : out UInt[5 bits])
// (toplevel/io_vga_color_g : out UInt[6 bits])
// (toplevel/io_vga_color_b : out UInt[5 bits])
// [Progress] at 44.008 : Generate Verilog to .
// [Warning] toplevel/axi_sdramCtrl/ctrl/chip_backupIn_fifo/fifo/logic_ram : Mem[2*21 bits].readAsync can only be write first into Verilog
// [Warning] toplevel/axi_ram_io_axi_arbiter/cmdRouteFork_throwWhen_translated_fifo/fifo/logic_ram : Mem[4*1 bits].readAsync can only be write first into Verilog
// [Warning] toplevel/axi_sdramCtrl_io_axi_arbiter/cmdRouteFork_throwWhen_translated_fifo/fifo/logic_ram : Mem[4*1 bits].readAsync can only be write first into Verilog
// [Warning] toplevel/axi_apbBridge_io_axi_arbiter/cmdRouteFork_throwWhen_translated_fifo/fifo/logic_ram : Mem[4*1 bits].readAsync can only be write first into Verilog
// [Warning] 584 signals were pruned. You can call printPruned on the backend report to get more informations.
// [Done] at 44.225
// import spinal.lib.soc.pinsec._
//
// res4_1: SpinalReport[Pinsec] = spinal.core.SpinalReport@443e7df1
