// %%
interp.configureCompiler(_.settings.processArguments(List("-Wconf:cat=deprecation:s"), true))
interp.load.module(os.Path(s"${System.getProperty("user.dir")}/../source/load-spinal.sc"))

// %%
class WhyNot extends Component{
   val ram = Mem(Bits(4 bit),16)
   out(ram.readWriteSync(in UInt(4 bit),in Bits(4 bit),in Bool(),in Bool()))
   out(ram.readWriteSync(in UInt(4 bit),in Bits(4 bit),in Bool(),in Bool()))
}
showRtl(new WhyNot)
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.05.29 08:21:48
// [Progress] at 0.000 : Elaborate components
// [scala-interpreter-1] WARN oshi.util.FileUtil - Configuration conflict: there is more than one oshi.properties file on the classpath: [jar:file:/Users/jayzw/Library/Caches/Coursier/v1/https/repo1.maven.org/maven2/com/github/oshi/oshi-core/6.4.0/oshi-core-6.4.0.jar!/oshi.properties, jar:file:/Users/jayzw/Library/Caches/Coursier/v1/https/repo1.maven.org/maven2/com/github/oshi/oshi-core/6.4.0/oshi-core-6.4.0-sources.jar!/oshi.properties]
// [Progress] at 0.226 : Checks and transforms
// (toplevel/??? : out Bits[4 bits])
// (toplevel/??? : out Bits[4 bits])
// [Progress] at 0.253 : Generate Verilog to rtl/
// [Done] at 0.290
// // Generator : SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// // Component : WhyNot
// // Git hash  : bc88ade176032b608ae9387996257abb2ecc0dc2
// // Date      : 29/05/2025, 08:21:49
//
// `timescale 1ns/1ps
//
// module WhyNot (
//   input  wire [3:0]    t_1,
//   input  wire [3:0]    t_2,
//   input  wire          t_3,
//   input  wire          t_4,
//   output wire [3:0]    t_7,
//   input  wire [3:0]    t_8,
//   input  wire [3:0]    t_9,
//   input  wire          t_10,
//   input  wire          t_11,
//   output wire [3:0]    t_14,
//   input  wire          clk,
//   input  wire          resetn
// );
//
//   reg        [3:0]    ram_spinal_port0;
//   reg        [3:0]    ram_spinal_port1;
//   wire       [3:0]    t_5;
//   wire       [3:0]    t_12;
//   reg [3:0] ram [0:15];
//
//   always @(posedge clk) begin
//     if(t_3) begin
//       ram_spinal_port0 <= ram[t_1];
//     end
//   end
//
//   always @(posedge clk) begin
//     if(t_3 && t_4 ) begin
//       ram[t_1] <= t_5;
//     end
//   end
//
//   always @(posedge clk) begin
//     if(t_10) begin
//       ram_spinal_port1 <= ram[t_8];
//     end
//   end
//
//   always @(posedge clk) begin
//     if(t_10 && t_11 ) begin
//       ram[t_8] <= t_12;
//     end
//   end
//
//   assign t_5 = t_2;
//   assign t_7 = ram_spinal_port0;
//   assign t_12 = t_9;
//   assign t_14 = ram_spinal_port1;
//
// endmodule
// defined class WhyNot

// %%
class Top extends Component{
  val myBits  = Bits(8 bits)
  val itMatch = myBits === M"00--10--" // - don't care value
}
showRtl(new Top)
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.05.29 16:58:18
// [Progress] at 30990.024 : Elaborate components
// [Progress] at 30990.029 : Checks and transforms
// [Progress] at 30990.032 : Generate Verilog to rtl/
// [Warning] 2 signals were pruned. You can call printPruned on the backend report to get more informations.
// [Done] at 30990.052
// // Generator : SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// // Component : Top
// // Git hash  : bc88ade176032b608ae9387996257abb2ecc0dc2
// // Date      : 29/05/2025, 16:58:19
//
// `timescale 1ns/1ps
//
// module Top (
// );
//
//   wire       [7:0]    myBits;
//   wire                itMatch;
//
//   assign itMatch = ((myBits & 8'hcc) == 8'h08);
//
// endmodule
// defined class Top
