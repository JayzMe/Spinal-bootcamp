// %%
interp.configureCompiler(_.settings.processArguments(List("-Wconf:cat=deprecation:s"), true))
interp.load.module(os.Path(s"${System.getProperty("user.dir")}/../source/load-spinal.sc"))
// Out:
// Compiling /Users/jayzw/Workspace/Personal/Spinal-bootcamp/ex/Main.sc

// %%
class TopLevel extends Component {
  val a = UInt(8 bits)
  a := 42
  a := 66 //Erease the a := 42 :(
}
showRtl(new TopLevel)
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.05.28 23:13:57
// [Progress] at 0.000 : Elaborate components
// [scala-interpreter-1] WARN oshi.util.FileUtil - Configuration conflict: there is more than one oshi.properties file on the classpath: [jar:file:/Users/jayzw/Library/Caches/Coursier/v1/https/repo1.maven.org/maven2/com/github/oshi/oshi-core/6.4.0/oshi-core-6.4.0.jar!/oshi.properties, jar:file:/Users/jayzw/Library/Caches/Coursier/v1/https/repo1.maven.org/maven2/com/github/oshi/oshi-core/6.4.0/oshi-core-6.4.0-sources.jar!/oshi.properties]
// [Progress] at 0.202 : Checks and transforms
// spinal.core.SpinalExit$.apply(Misc.scala:459)
// spinal.core.SpinalError$.apply(Misc.scala:514)
// spinal.core.internals.PhaseContext.checkPendingErrors(Phase.scala:178)
// spinal.core.internals.PhaseContext.doPhase(Phase.scala:194)
// spinal.core.internals.SpinalVerilogBoot$.$anonfun$singleShot$12(Phase.scala:3296)
// spinal.core.internals.SpinalVerilogBoot$.$anonfun$singleShot$12$adapted(Phase.scala:3294)
// scala.collection.IterableOnceOps.foreach(IterableOnce.scala:575)
// scala.collection.IterableOnceOps.foreach$(IterableOnce.scala:573)
// scala.collection.AbstractIterable.foreach(Iterable.scala:933)
// spinal.core.internals.SpinalVerilogBoot$.$anonfun$singleShot$7(Phase.scala:3294)
// spinal.core.ScopeProperty$.sandbox(ScopeProperty.scala:71)
// spinal.core.internals.SpinalVerilogBoot$.singleShot(Phase.scala:3225)
// spinal.core.internals.SpinalVerilogBoot$.apply(Phase.scala:3194)
// spinal.core.Spinal$.apply(Spinal.scala:434)
// spinal.core.SpinalConfig.generate(Spinal.scala:190)
// ammonite.$file.dummy.$up.source.load$minusspinal$Helper.showRtl(Main.sc:38)
// ammonite.$sess.cmd1$Helper.<init>(cmd1.sc:6)
// ammonite.$sess.cmd1$.<clinit>(cmd1.sc:7)
// ammonite.$sess.cmd1.$main(cmd1.sc)
// java.base/jdk.internal.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
// java.base/jdk.internal.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:77)
// java.base/jdk.internal.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
// java.base/java.lang.reflect.Method.invoke(Method.java:569)
// ammonite.runtime.Evaluator$$anon$1.$anonfun$evalMain$1(Evaluator.scala:108)
// ammonite.util.Util$.withContextClassloader(Util.scala:24)
// ammonite.runtime.Evaluator$$anon$1.evalMain(Evaluator.scala:90)
// ammonite.runtime.Evaluator$$anon$1.$anonfun$processLine$2(Evaluator.scala:127)
// ammonite.util.Catching.map(Res.scala:117)
// ammonite.runtime.Evaluator$$anon$1.$anonfun$processLine$1(Evaluator.scala:121)
// ammonite.util.Res$Success.flatMap(Res.scala:62)
// ammonite.runtime.Evaluator$$anon$1.processLine(Evaluator.scala:120)
// ammonite.interp.Interpreter.$anonfun$evaluateLine$5(Interpreter.scala:301)
// ammonite.util.Res$Success.flatMap(Res.scala:62)
// ammonite.interp.Interpreter.$anonfun$evaluateLine$2(Interpreter.scala:284)
// ammonite.util.Catching.flatMap(Res.scala:115)
// ammonite.interp.Interpreter.evaluateLine(Interpreter.scala:283)
// ammonite.interp.Interpreter.$anonfun$processLine$6(Interpreter.scala:271)
// ammonite.util.Res$Success.flatMap(Res.scala:62)
// ammonite.interp.Interpreter.$anonfun$processLine$4(Interpreter.scala:254)
// ammonite.util.Res$Success.flatMap(Res.scala:62)
// ammonite.interp.Interpreter.$anonfun$processLine$2(Interpreter.scala:247)
// ammonite.util.Catching.flatMap(Res.scala:115)
// ammonite.interp.Interpreter.processLine(Interpreter.scala:246)
// almond.Execute.$anonfun$ammResult$7(Execute.scala:276)
// almond.internals.CaptureImpl.$anonfun$apply$2(CaptureImpl.scala:52)
// scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
// scala.Console$.withErr(Console.scala:193)
// almond.internals.CaptureImpl.$anonfun$apply$1(CaptureImpl.scala:44)
// scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
// scala.Console$.withOut(Console.scala:164)
// almond.internals.CaptureImpl.apply(CaptureImpl.scala:44)
// almond.Execute.capturingOutput(Execute.scala:178)
// almond.Execute.$anonfun$ammResult$6(Execute.scala:263)
// almond.Execute.$anonfun$withClientStdin$1(Execute.scala:157)
// scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
// scala.Console$.withIn(Console.scala:227)
// almond.Execute.withClientStdin(Execute.scala:153)
// almond.Execute.$anonfun$ammResult$5(Execute.scala:263)
// almond.Execute.withInputManager(Execute.scala:143)
// almond.Execute.$anonfun$ammResult$4(Execute.scala:262)
// ammonite.repl.Signaller.apply(Signaller.scala:28)
// almond.Execute.interruptible(Execute.scala:204)
// almond.Execute.$anonfun$ammResult$3(Execute.scala:261)
// ammonite.util.Res$Success.flatMap(Res.scala:62)
// almond.Execute.$anonfun$ammResult$1(Execute.scala:248)
// almond.Execute.withOutputHandler(Execute.scala:169)
// almond.Execute.ammResult(Execute.scala:239)
// almond.Execute.apply(Execute.scala:397)
// almond.ScalaInterpreter.execute(ScalaInterpreter.scala:158)
// almond.interpreter.InterpreterToIOInterpreter.$anonfun$execute$2(InterpreterToIOInterpreter.scala:70)
// cats.effect.internals.IORunLoop$.cats$effect$internals$IORunLoop$$loop(IORunLoop.scala:108)
// cats.effect.internals.IORunLoop$RestartCallback.signal(IORunLoop.scala:480)
// cats.effect.internals.IORunLoop$RestartCallback.apply(IORunLoop.scala:501)
// cats.effect.internals.IORunLoop$RestartCallback.apply(IORunLoop.scala:439)
// cats.effect.internals.IOShift$Tick.run(IOShift.scala:36)
// java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1136)
// java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
// java.base/java.lang.Thread.run(Thread.java:840)
//
// **********************************************************************************************
// [Warning] Elaboration failed (2 errors).
//           Spinal will restart with scala trace to help you to find the problem.
// **********************************************************************************************
//
// [Progress] at 0.221 : Elaborate components
// [Progress] at 0.222 : Checks and transforms
// spinal.core.SpinalExit:
//
//
//  Error detected in phase PhaseCheck_noLatchNoOverride
// ********************************************************************************
// ********************************************************************************
//
// ASSIGNMENT OVERLAP completely the previous one of (toplevel/a :  UInt[8 bits])
//     ammonite.$sess.cmd1$Helper$TopLevel.<init>(cmd1.sc:4)
//     ammonite.$sess.cmd1$Helper.$anonfun$res1_1$1(cmd1.sc:6)
//
//
// ********************************************************************************
// ********************************************************************************
//
// Design's errors are listed above.
// SpinalHDL compiler exit stack :
//
//   spinal.core.SpinalExit$.apply(Misc.scala:459)
//   spinal.core.SpinalError$.apply(Misc.scala:514)
//   spinal.core.internals.PhaseContext.checkPendingErrors(Phase.scala:178)
//   spinal.core.internals.PhaseContext.doPhase(Phase.scala:194)
//   spinal.core.internals.SpinalVerilogBoot$.$anonfun$singleShot$12(Phase.scala:3296)
//   spinal.core.internals.SpinalVerilogBoot$.$anonfun$singleShot$12$adapted(Phase.scala:3294)
//   scala.collection.IterableOnceOps.foreach(IterableOnce.scala:575)
//   scala.collection.IterableOnceOps.foreach$(IterableOnce.scala:573)
//   scala.collection.AbstractIterable.foreach(Iterable.scala:933)
//   spinal.core.internals.SpinalVerilogBoot$.$anonfun$singleShot$7(Phase.scala:3294)
//   spinal.core.ScopeProperty$.sandbox(ScopeProperty.scala:71)
//   spinal.core.internals.SpinalVerilogBoot$.singleShot(Phase.scala:3225)
//   spinal.core.internals.SpinalVerilogBoot$.apply(Phase.scala:3220)
//   spinal.core.Spinal$.apply(Spinal.scala:434)
//   spinal.core.SpinalConfig.generate(Spinal.scala:190)
//   ammonite.$file.dummy.$up.source.load$minusspinal$Helper.showRtl(Main.sc:38)
//   ammonite.$sess.cmd1$Helper.<init>(cmd1.sc:6)
//   ammonite.$sess.cmd1$.<clinit>(cmd1.sc:7)

// %%
class TopLevel extends Component {
  val a = UInt(8 bits)
  a := 42
  a.allowOverride
  a := 66
}
showRtl(new TopLevel)
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.05.28 23:14:16
// [Progress] at 19.095 : Elaborate components
// [Progress] at 19.096 : Checks and transforms
// [Progress] at 19.113 : Generate Verilog to rtl/
// [Warning] 1 signals were pruned. You can call printPruned on the backend report to get more informations.
// [Done] at 19.151
// // Generator : SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// // Component : TopLevel
// // Git hash  : bc88ade176032b608ae9387996257abb2ecc0dc2
// // Date      : 28/05/2025, 23:14:16
//
// `timescale 1ns/1ps
//
// module TopLevel (
// );
//
//   reg        [7:0]    a;
//   function [7:0] zz_a(input dummy);
//     begin
//       zz_a = 8'h2a;
//       zz_a = 8'h42;
//     end
//   endfunction
//   wire [7:0] t_1;
//
//   assign t_1 = zz_a(1'b0);
//   always @(*) a = t_1;
//
// endmodule
// defined class TopLevel

// %%
class TopLevel extends Component {
  val clkA = ClockDomain.external("clkA")
  val clkB = ClockDomain.external("clkB")

  val regA = clkA(Reg(UInt(8 bits)))   //PlayDev.scala:834
  val regB = clkB(Reg(UInt(8 bits)))   //PlayDev.scala:835

  val tmp = regA + regA                //PlayDev.scala:838
  regB := tmp
}
showRtl(new TopLevel)
// Out:
// [Runtime] SpinalHDL v1.12.0    git head : 1aa7d7b5732f11cca2dd83bacc2a4cb92ca8e5c9
// [Runtime] JVM max memory : 4096.0MiB
// [Runtime] Current date : 2025.05.28 23:26:50
// [Progress] at 773.621 : Elaborate components
// [Progress] at 773.624 : Checks and transforms
// spinal.core.SpinalExit$.apply(Misc.scala:459)
// spinal.core.SpinalError$.apply(Misc.scala:514)
// spinal.core.internals.PhaseContext.checkPendingErrors(Phase.scala:178)
// spinal.core.internals.PhaseContext.doPhase(Phase.scala:194)
// spinal.core.internals.SpinalVerilogBoot$.$anonfun$singleShot$12(Phase.scala:3296)
// spinal.core.internals.SpinalVerilogBoot$.$anonfun$singleShot$12$adapted(Phase.scala:3294)
// scala.collection.IterableOnceOps.foreach(IterableOnce.scala:575)
// scala.collection.IterableOnceOps.foreach$(IterableOnce.scala:573)
// scala.collection.AbstractIterable.foreach(Iterable.scala:933)
// spinal.core.internals.SpinalVerilogBoot$.$anonfun$singleShot$7(Phase.scala:3294)
// spinal.core.ScopeProperty$.sandbox(ScopeProperty.scala:71)
// spinal.core.internals.SpinalVerilogBoot$.singleShot(Phase.scala:3225)
// spinal.core.internals.SpinalVerilogBoot$.apply(Phase.scala:3194)
// spinal.core.Spinal$.apply(Spinal.scala:434)
// spinal.core.SpinalConfig.generate(Spinal.scala:190)
// ammonite.$file.dummy.$up.source.load$minusspinal$Helper.showRtl(Main.sc:38)
// ammonite.$sess.cmd3$Helper.<init>(cmd3.sc:11)
// ammonite.$sess.cmd3$.<clinit>(cmd3.sc:7)
// ammonite.$sess.cmd3.$main(cmd3.sc)
// java.base/jdk.internal.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
// java.base/jdk.internal.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:77)
// java.base/jdk.internal.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
// java.base/java.lang.reflect.Method.invoke(Method.java:569)
// ammonite.runtime.Evaluator$$anon$1.$anonfun$evalMain$1(Evaluator.scala:108)
// ammonite.util.Util$.withContextClassloader(Util.scala:24)
// ammonite.runtime.Evaluator$$anon$1.evalMain(Evaluator.scala:90)
// ammonite.runtime.Evaluator$$anon$1.$anonfun$processLine$2(Evaluator.scala:127)
// ammonite.util.Catching.map(Res.scala:117)
// ammonite.runtime.Evaluator$$anon$1.$anonfun$processLine$1(Evaluator.scala:121)
// ammonite.util.Res$Success.flatMap(Res.scala:62)
// ammonite.runtime.Evaluator$$anon$1.processLine(Evaluator.scala:120)
// ammonite.interp.Interpreter.$anonfun$evaluateLine$5(Interpreter.scala:301)
// ammonite.util.Res$Success.flatMap(Res.scala:62)
// ammonite.interp.Interpreter.$anonfun$evaluateLine$2(Interpreter.scala:284)
// ammonite.util.Catching.flatMap(Res.scala:115)
// ammonite.interp.Interpreter.evaluateLine(Interpreter.scala:283)
// ammonite.interp.Interpreter.$anonfun$processLine$6(Interpreter.scala:271)
// ammonite.util.Res$Success.flatMap(Res.scala:62)
// ammonite.interp.Interpreter.$anonfun$processLine$4(Interpreter.scala:254)
// ammonite.util.Res$Success.flatMap(Res.scala:62)
// ammonite.interp.Interpreter.$anonfun$processLine$2(Interpreter.scala:247)
// ammonite.util.Catching.flatMap(Res.scala:115)
// ammonite.interp.Interpreter.processLine(Interpreter.scala:246)
// almond.Execute.$anonfun$ammResult$7(Execute.scala:276)
// almond.internals.CaptureImpl.$anonfun$apply$2(CaptureImpl.scala:52)
// scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
// scala.Console$.withErr(Console.scala:193)
// almond.internals.CaptureImpl.$anonfun$apply$1(CaptureImpl.scala:44)
// scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
// scala.Console$.withOut(Console.scala:164)
// almond.internals.CaptureImpl.apply(CaptureImpl.scala:44)
// almond.Execute.capturingOutput(Execute.scala:178)
// almond.Execute.$anonfun$ammResult$6(Execute.scala:263)
// almond.Execute.$anonfun$withClientStdin$1(Execute.scala:157)
// scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
// scala.Console$.withIn(Console.scala:227)
// almond.Execute.withClientStdin(Execute.scala:153)
// almond.Execute.$anonfun$ammResult$5(Execute.scala:263)
// almond.Execute.withInputManager(Execute.scala:143)
// almond.Execute.$anonfun$ammResult$4(Execute.scala:262)
// ammonite.repl.Signaller.apply(Signaller.scala:28)
// almond.Execute.interruptible(Execute.scala:204)
// almond.Execute.$anonfun$ammResult$3(Execute.scala:261)
// ammonite.util.Res$Success.flatMap(Res.scala:62)
// almond.Execute.$anonfun$ammResult$1(Execute.scala:248)
// almond.Execute.withOutputHandler(Execute.scala:169)
// almond.Execute.ammResult(Execute.scala:239)
// almond.Execute.apply(Execute.scala:397)
// almond.ScalaInterpreter.execute(ScalaInterpreter.scala:158)
// almond.interpreter.InterpreterToIOInterpreter.$anonfun$execute$2(InterpreterToIOInterpreter.scala:70)
// cats.effect.internals.IORunLoop$.cats$effect$internals$IORunLoop$$loop(IORunLoop.scala:108)
// cats.effect.internals.IORunLoop$RestartCallback.signal(IORunLoop.scala:480)
// cats.effect.internals.IORunLoop$RestartCallback.apply(IORunLoop.scala:501)
// cats.effect.internals.IORunLoop$RestartCallback.apply(IORunLoop.scala:439)
// cats.effect.internals.IOShift$Tick.run(IOShift.scala:36)
// java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1136)
// java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
// java.base/java.lang.Thread.run(Thread.java:840)
//
// **********************************************************************************************
// [Warning] Elaboration failed (3 errors).
//           Spinal will restart with scala trace to help you to find the problem.
// **********************************************************************************************
//
// [Progress] at 773.646 : Elaborate components
// [Progress] at 773.648 : Checks and transforms
// spinal.core.SpinalExit:
//
//
//  Error detected in phase PhaseCheckCrossClock
// ********************************************************************************
// ********************************************************************************
//
// CLOCK CROSSING VIOLATION :
// - Source            : (toplevel/regA :  UInt[8 bits]) ammonite.$sess.cmd3$Helper$TopLevel.$anonfun$regA$2(cmd3.sc:5)
// - Source clock      : (clkA_clk :  Bool)
// - Destination       : (toplevel/regB :  UInt[8 bits]) ammonite.$sess.cmd3$Helper$TopLevel.$anonfun$regB$2(cmd3.sc:6)
// - Destination clock : (clkB_clk :  Bool)
// - Source declaration :
//     ammonite.$sess.cmd3$Helper$TopLevel.$anonfun$regA$2(cmd3.sc:5)
//     ammonite.$sess.cmd3$Helper$TopLevel.$anonfun$regA$1(cmd3.sc:5)
//     ammonite.$sess.cmd3$Helper$TopLevel.<init>(cmd3.sc:5)
//     ammonite.$sess.cmd3$Helper.$anonfun$res3_1$1(cmd3.sc:11)
//
//
// - Destination declaration :
//     ammonite.$sess.cmd3$Helper$TopLevel.$anonfun$regB$2(cmd3.sc:6)
//     ammonite.$sess.cmd3$Helper$TopLevel.$anonfun$regB$1(cmd3.sc:6)
//     ammonite.$sess.cmd3$Helper$TopLevel.<init>(cmd3.sc:6)
//     ammonite.$sess.cmd3$Helper.$anonfun$res3_1$1(cmd3.sc:11)
//
//
// - Connection path :
//       >>> (toplevel/regA :  UInt[8 bits]) at ammonite.$sess.cmd3$Helper$TopLevel.$anonfun$regA$2(cmd3.sc:5) >>>
//       >>> (toplevel/tmp :  UInt[8 bits]) at ammonite.$sess.cmd3$Helper$TopLevel.<init>(cmd3.sc:8) >>>
//       >>> (toplevel/regB :  UInt[8 bits]) at ammonite.$sess.cmd3$Helper$TopLevel.$anonfun$regB$2(cmd3.sc:6) >>>
//
//
// ********************************************************************************
// ********************************************************************************
//
// Design's errors are listed above.
// SpinalHDL compiler exit stack :
//
//   spinal.core.SpinalExit$.apply(Misc.scala:459)
//   spinal.core.SpinalError$.apply(Misc.scala:514)
//   spinal.core.internals.PhaseContext.checkPendingErrors(Phase.scala:178)
//   spinal.core.internals.PhaseContext.doPhase(Phase.scala:194)
//   spinal.core.internals.SpinalVerilogBoot$.$anonfun$singleShot$12(Phase.scala:3296)
//   spinal.core.internals.SpinalVerilogBoot$.$anonfun$singleShot$12$adapted(Phase.scala:3294)
//   scala.collection.IterableOnceOps.foreach(IterableOnce.scala:575)
//   scala.collection.IterableOnceOps.foreach$(IterableOnce.scala:573)
//   scala.collection.AbstractIterable.foreach(Iterable.scala:933)
//   spinal.core.internals.SpinalVerilogBoot$.$anonfun$singleShot$7(Phase.scala:3294)
//   spinal.core.ScopeProperty$.sandbox(ScopeProperty.scala:71)
//   spinal.core.internals.SpinalVerilogBoot$.singleShot(Phase.scala:3225)
//   spinal.core.internals.SpinalVerilogBoot$.apply(Phase.scala:3220)
//   spinal.core.Spinal$.apply(Spinal.scala:434)
//   spinal.core.SpinalConfig.generate(Spinal.scala:190)
//   ammonite.$file.dummy.$up.source.load$minusspinal$Helper.showRtl(Main.sc:38)
//   ammonite.$sess.cmd3$Helper.<init>(cmd3.sc:11)
//   ammonite.$sess.cmd3$.<clinit>(cmd3.sc:7)
